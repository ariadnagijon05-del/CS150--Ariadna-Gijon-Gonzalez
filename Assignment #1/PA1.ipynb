# %% [markdown]
# # Ariadna Gijon - Markdown Practice

# %% [markdown]
# ### About Me
# My name is Ariadna Gijon. I am an Accounting and Fianance double major. I chose Data Analysis as my minor because coding is becoming a more and more essential field. With some background knowledge in coding I hope to have some additional valueable information to share in my future employments.

# %% [markdown]
# - Programming Assignments (5)
# - Quizzes (4)
# - Attendance / In - Class Participation
# - Exams (2)
# - Projects (2)

# %% [markdown]
# 1. Module 1 : Course Introduction, Variables, Simple Data Types, and Github Discussion.
# 2. Module 2 : Lists and Tuples Part 1; Part 1 Continued.
# 3. Module 3 : If Statements.
# 4. Module 4 : Loops.
# 5. Module 5 : Lists and Tuples Part 2.
# 6. Module 6 : Dictionaries.
# 7. Module 7 : Sets, Functions, and Libraries.
# 8. Module 8 : Class, Datatypes, and Exceptions.
# 9. Module 9 : NumPy Arrays
# 10. Module 10 : Pandas and Files Excerpt

# %% [markdown]
# The primary coding language I will be learning about in this class is **Python**.

# %% [markdown]
# I am using *Jupyter Notebook* to create and edit my .ipynb file.

# %% [markdown]
# Today I `worked on Module 1 Notes so that I can be caught up for class on Monday. I also tried to work ahead by completing assignment 1.`

# %% [markdown]
# My GitHub Account : [GitHub](https://github.com/ariadnagijon05-del)

# %% [markdown]
# ![python](university-seal-1.png)

# %% [markdown]
# Today I did various things with Jupytr notebook. I created headers effectively, I made bulleted and ordered lists, and also, created coding to italicize or bolden words. Finnaly, I also used python to highlight blocks of words, create a hyperlink and add photos to my coding workbook.
